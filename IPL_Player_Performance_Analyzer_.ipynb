# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-1310/ipl-player-performance-analyzer/blob/main/IPL_Player_Performance_Analyzer_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏏 IPL Player Performance Analyzer (Beginner Project)
# Built using Python, Pandas & Seaborn
# Analyzed batting stats to identify top performers by Runs, Strike Rate, and Batting Average.

# %%
# Importing essential libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set(style="whitegrid")

from google.colab import files
uploaded = files.upload()

# %%
uploaded.keys()
# Out:
# dict_keys(['most_runs_average_strikerate (5).csv'])

# %%
df = pd.read_csv('most_runs_average_strikerate (5).csv')
df.head()
# Out:
#      batsman  total_runs  out  numberofballs    average  strikerate
# 0    V Kohli        5426  152           4111  35.697368  131.987351
# 1   SK Raina        5386  160           3916  33.662500  137.538304
# 2  RG Sharma        4902  161           3742  30.447205  130.999466
# 3  DA Warner        4717  114           3292  41.377193  143.286756
# 4   S Dhawan        4601  137           3665  33.583942  125.538881

# %%
df.columns
# Out:
# Index(['batsman', 'total_runs', 'out', 'numberofballs', 'average',
#        'strikerate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
df.describe()
# Out:
#         total_runs         out  numberofballs     average  strikerate
# count   516.000000  516.000000     516.000000  482.000000  516.000000
# mean    430.625969   17.063953     335.645349   16.355074  105.433442
# std     882.275431   28.124511     663.593679   11.146222   39.633938
# min       0.000000    0.000000       1.000000    0.000000    0.000000
# 25%      15.000000    2.000000      17.000000    8.000000   84.362069
# 50%      74.000000    5.500000      68.000000   14.607143  111.651584
# 75%     340.500000   18.000000     290.000000   23.657609  130.499036
# max    5426.000000  161.000000    4111.000000   88.000000  250.000000

# %%
top_run_scorers = df.sort_values(by='total_runs',ascending=False).head(10)
top_run_scorers[['batsman','total_runs']]
# Out:
#           batsman  total_runs
# 0         V Kohli        5426
# 1        SK Raina        5386
# 2       RG Sharma        4902
# 3       DA Warner        4717
# 4        S Dhawan        4601
# 5        CH Gayle        4525
# 6        MS Dhoni        4450
# 7      RV Uthappa        4420
# 8  AB de Villiers        4414
# 9       G Gambhir        4219

# %%
top_strike_rate = df[df['numberofballs'] > 100].sort_values(by='strikerate', ascending=False).head(10)
top_strike_rate[['batsman', 'strikerate']]
# Out:
#            batsman  strikerate
# 49      AD Russell  188.164894
# 82       SP Narine  171.397380
# 138          M Ali  170.621469
# 153    BCJ Cutting  169.503546
# 171  CR Brathwaite  165.454545
# 38         RR Pant  164.985994
# 50      GJ Maxwell  162.152778
# 109     J Bairstow  161.619718
# 177       N Pooran  160.377358
# 103      CH Morris  158.715596

# %%
top_average = df[df['out'] > 10].sort_values(by='average', ascending=False).head(10)
top_average[['batsman', 'average']]
# Out:
#             batsman    average
# 97          HM Amla  44.384615
# 8    AB de Villiers  42.442308
# 30        JP Duminy  41.448980
# 3         DA Warner  41.377193
# 5          CH Gayle  41.136364
# 61        ML Hayden  41.000000
# 31         KL Rahul  40.571429
# 65      LMP Simmons  39.962963
# 106         OA Shah  38.923077
# 55    KS Williamson  38.500000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='total_runs', y='batsman', data=top_run_scorers, palette='viridis')
plt.title('Top 10 IPL Run Scorers', fontsize=16)
plt.xlabel('Total Runs')
plt.ylabel('Player')
plt.show()
# Out:
# /tmp/ipython-input-1418429313.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='total_runs', y='batsman', data=top_run_scorers, palette='viridis')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='strikerate', y='batsman', data=top_strike_rate, palette='rocket')
plt.title('Top 10 IPL Strike Rates (Min 100 Balls)', fontsize=16)
plt.xlabel('Strike Rate')
plt.ylabel('Player')
plt.show()
# Out:
# /tmp/ipython-input-1881498374.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='strikerate', y='batsman', data=top_strike_rate, palette='rocket')

# %% [markdown]
# plt.figure(figsize=(12, 6))
# sns.barplot(x='average', y='batsman', data=top_average, palette='coolwarm')
# plt.title('Top 10 IPL Batting Averages (Min 10 Outs)', fontsize=16)
# plt.xlabel('Batting Average')
# plt.ylabel('Player')
# plt.show()
